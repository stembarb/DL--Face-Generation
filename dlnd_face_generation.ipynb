# %% [markdown]
# # Face Generation
#
# In this project, I'll define and train a DCGAN on a dataset of faces. My goal is to get a generator network to generate *new* images of faces that look as realistic as possible!
#
# The project is broken down into a series of tasks from **loading in data to defining and training adversarial networks**. At the end of the notebook, I'll visualize the results of trained Generator to see how it performs; my generated samples should look like fairly realistic faces with small amounts of noise.
#
# ### Get the Data
#
# I'll be using the [CelebFaces Attributes Dataset (CelebA)](http://mmlab.ie.cuhk.edu.hk/projects/CelebA.html) to train adversarial networks.
#
# ### Pre-processed Data
#
# Since the project's main focus is on building the GANs, *some* of the pre-processing has been already done. Each of the CelebA images has been cropped to remove parts of the image that don't include a face, then resized down to 64x64x3 NumPy images. Some sample data is show below.
#
# <img src='assets/processed_face_data.png' width=60% />
#
# > To work locally, download this data [by clicking here](https://s3.amazonaws.com/video.udacity-data.com/topher/2018/November/5be7eb6f_processed-celeba-small/processed-celeba-small.zip). This is a zip file that needs to be extracted in the home directory of this notebook for further loading and processing.

# %%
# can comment out after executing
# !unzip processed_celeba_small.zip

# %%
data_dir = 'processed_celeba_small/'

"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
import pickle as pkl
import matplotlib.pyplot as plt
import numpy as np
import problem_unittests as tests
#import helper

# %matplotlib inline

# %% [markdown]
# ## Visualize the CelebA Data
#
# The [CelebA](http://mmlab.ie.cuhk.edu.hk/projects/CelebA.html) dataset contains over 200,000 celebrity images with annotations. Since you're going to be generating faces, you won't need the annotations, you'll only need the images. Note that these are color images with [3 color channels (RGB)](https://en.wikipedia.org/wiki/Channel_(digital_image)#RGB_Images) each.
#
# ### Pre-process and Load the Data
#
# Since the project's main focus is on building the GANs, we've done *some* of the pre-processing for you. Each of the CelebA images has been cropped to remove parts of the image that don't include a face, then resized down to 64x64x3 NumPy images. This *pre-processed* dataset is a smaller subset of the very large CelebA data.
#
# > There are a few other steps that you'll need to **transform** this data and create a **DataLoader**.
#
# #### Exercise: Complete the following `get_dataloader` function, such that it satisfies these requirements:
#
# * Your images should be square, Tensor images of size `image_size x image_size` in the x and y dimension.
# * Your function should return a DataLoader that shuffles and batches these Tensor images.
#
# #### ImageFolder
#
# To create a dataset given a directory of images, it's recommended that you use PyTorch's [ImageFolder](https://pytorch.org/docs/stable/torchvision/datasets.html#imagefolder) wrapper, with a root directory `processed_celeba_small/` and data transformation passed in.

# %%
# necessary imports
import torch
from torchvision import datasets
from torchvision import transforms

# %%
def get_dataloader(batch_size, image_size, data_dir='processed-celeba-small/'):
    """
    Batch the neural network data using DataLoader
    :param batch_size: The size of each batch; the number of images in a batch
    :param img_size: The square size of the image data (x, y)
    :param data_dir: Directory where image data is located
    :return: DataLoader with batched data
    """
    
    # TODO: Implement function and return a dataloader
    transform = transforms.Compose([transforms.Resize(image_size),
                                    transforms.ToTensor()])
    
    dataset = datasets.ImageFolder(data_dir, transform=transform)
    
    data_loader = torch.utils.data.DataLoader(dataset=dataset, batch_size=batch_size, shuffle=True)
    
    return data_loader

# %% [markdown]
# ## Create a DataLoader
#
# #### Exercise: Create a DataLoader `celeba_train_loader` with appropriate hyperparameters.
#
# Call the above function and create a dataloader to view images.
# * You can decide on any reasonable `batch_size` parameter
# * Your `image_size` **must be** `32`. Resizing the data to a smaller size will make for faster training, while still creating convincing images of faces!

# %%
# Define function hyperparameters
batch_size = 128
img_size = 32

"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
# Call your function and get a dataloader
celeba_train_loader = get_dataloader(batch_size, img_size)

# %% [markdown]
# Next, you can view some images! You should seen square images of somewhat-centered faces.
#
# Note: You'll need to convert the Tensor images into a NumPy type and transpose the dimensions to correctly display an image, suggested `imshow` code is below, but it may not be perfect.

# %%
# helper display function
def imshow(img):
    npimg = img.numpy()
    plt.imshow(np.transpose(npimg, (1, 2, 0)))

"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
# obtain one batch of training images
dataiter = iter(celeba_train_loader)
images, _ = dataiter.next() # _ for no labels

# plot the images in the batch, along with the corresponding labels
fig = plt.figure(figsize=(20, 4))
plot_size=20
for idx in np.arange(plot_size):
    ax = fig.add_subplot(2, plot_size/2, idx+1, xticks=[], yticks=[])
    imshow(images[idx])

# %% [markdown]
# #### Exercise: Pre-process your image data and scale it to a pixel range of -1 to 1
#
# You need to do a bit of pre-processing; you know that the output of a `tanh` activated generator will contain pixel values in a range from -1 to 1, and so, we need to rescale our training images to a range of -1 to 1. (Right now, they are in a range from 0-1.)

# %%
# TODO: Complete the scale function
def scale(x, feature_range=(-1, 1)):
    ''' Scale takes in an image x and returns that image, scaled
       with a feature_range of pixel values from -1 to 1. 
       This function assumes that the input x is already scaled from 0-1.'''
    # assume x is scaled to (0, 1)
    # scale to feature_range and return scaled x
    min, max = feature_range
    x = x * (max - min) + min
    
    return x

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
# check scaled range
# should be close to -1 to 1
img = images[0]
scaled_img = scale(img)

print('Min: ', scaled_img.min())
print('Max: ', scaled_img.max())
# Out:
# Min:  tensor(-0.9922)
# Max:  tensor(0.9451)

# %% [markdown]
# ---
# # Define the Model
#
# A GAN is comprised of two adversarial networks, a discriminator and a generator.
#
# ## Discriminator
#
# Your first task will be to define the discriminator. This is a convolutional classifier like you've built before, only without any maxpooling layers. To deal with this complex data, it's suggested you use a deep network with **normalization**. You are also allowed to create any helper functions that may be useful.
#
# #### Exercise: Complete the Discriminator class
# * The inputs to the discriminator are 32x32x3 tensor images
# * The output should be a single value that will indicate whether a given image is real or fake

# %%
import torch.nn as nn
import torch.nn.functional as F

# %%
# helper function to create convolutional layers
def conv(in_channels, out_channels, kernel_size=4, stride=2, padding=1, batch_norm=True):
    """
    Creates a convolutional layer.
    Batch normalization is optional.
    """
    layers = []
    
    conv_layer = nn.Conv2d(in_channels, out_channels, kernel_size, stride, padding, bias=False)
    layers.append(conv_layer)

    if batch_norm:
        layers.append(nn.BatchNorm2d(out_channels))

    return nn.Sequential(*layers)

# %%
class Discriminator(nn.Module):

    def __init__(self, conv_dim):
        """
        Initialize the Discriminator Module
        :param conv_dim: The depth of the first convolutional layer
        """
        super(Discriminator, self).__init__()

        self.conv_dim = conv_dim

        # conv layers
        # 32x32
        self.conv1 = conv(3, conv_dim, batch_norm= False)
        # 16x16
        self.conv2 = conv(conv_dim, conv_dim*2)
        # 8x8
        self.conv3 = conv(conv_dim*2, conv_dim*4)
        # 4x4
        self.conv4 = conv(conv_dim*4, conv_dim*8)
        # fully connected layer
        self.fc = nn.Linear(conv_dim*8*2*2,1)
        
    def forward(self, x):
        """
        Forward propagation of the neural network
        :param x: The input to the neural network     
        :return: Discriminator logits; the output of the neural network
        """
        # define feedforward behavior
        x = F.leaky_relu(self.conv1(x),0.2)
        x = F.leaky_relu(self.conv2(x),0.2)
        x = F.leaky_relu(self.conv3(x),0.2)
        x = F.leaky_relu(self.conv4(x),0.2)
        
        # flatten the image
        x = x.view(-1, self.conv_dim*8*2*2)
        
        # final output layer
        x = self.fc(x)

        return x


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_discriminator(Discriminator)
# Out:
# Tests Passed

# %% [markdown]
# ## Generator
#
# The generator should upsample an input and generate a *new* image of the same size as our training data `32x32x3`. This should be mostly transpose convolutional layers with normalization applied to the outputs.
#
# #### Exercise: Complete the Generator class
# * The inputs to the generator are vectors of some length `z_size`
# * The output should be a image of shape `32x32x3`

# %%
# helper function to create transposed convolutional layers
def deconv(in_channels, out_channels, kernel_size = 4, stride = 2, padding = 1, batch_norm = True):
    """
    Creates a transposed-convolutional layer.
    Batch normalization is optional.
    """
    layers = []
    
    conv_layer = nn.ConvTranspose2d(in_channels, out_channels, kernel_size, stride, padding, bias = False)
    layers.append(conv_layer)
    
    if batch_norm:
        layers.append(nn.BatchNorm2d(out_channels))
        
    return nn.Sequential(*layers)

# %%
class Generator(nn.Module):
    
    def __init__(self, z_size, conv_dim):
        """
        Initialize the Generator Module
        :param z_size: The length of the input latent vector, z
        :param conv_dim: The depth of the inputs to the *last* transpose convolutional layer
        """
        super(Generator, self).__init__()
        self.conv_dim = conv_dim
        
        # complete init function
        
        # fully connected layer
        self.fc = nn.Linear(z_size, conv_dim*8*2*2)
        
        # transpose conv layers
        self.deconv1 = deconv(conv_dim*8, conv_dim*4)
        self.deconv2 = deconv(conv_dim*4, conv_dim*2)
        self.deconv3 = deconv(conv_dim*2, conv_dim)
        self.deconv4 = deconv(conv_dim,3, batch_norm=False)

    def forward(self, x):
        """
        Forward propagation of the neural network
        :param x: The input to the neural network     
        :return: A 32x32x3 Tensor image as output
        """
        # define feedforward behavior
        x = self.fc(x)
        x = x.view(-1, self.conv_dim * 8, 2, 2)
        
        # transpose conv layers
        x = F.relu(self.deconv1(x))
        x = F.relu(self.deconv2(x))
        x = F.relu(self.deconv3(x))
        x = torch.tanh(self.deconv4(x))
        
        return x

"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_generator(Generator)
# Out:
# Tests Passed

# %% [markdown]
# ## Initialize the weights of your networks
#
# To help your models converge, you should initialize the weights of the convolutional and linear layers in your model. From reading the [original DCGAN paper](https://arxiv.org/pdf/1511.06434.pdf), they say:
# > All weights were initialized from a zero-centered Normal distribution with standard deviation 0.02.
#
# So, your next task will be to define a weight initialization function that does just this!
#
# You can refer back to the lesson on weight initialization or even consult existing model code, such as that from [the `networks.py` file in CycleGAN Github repository](https://github.com/junyanz/pytorch-CycleGAN-and-pix2pix/blob/master/models/networks.py) to help you complete this function.
#
# #### Exercise: Complete the weight initialization function
#
# * This should initialize only **convolutional** and **linear** layers
# * Initialize the weights to a normal distribution, centered around 0, with a standard deviation of 0.02.
# * The bias terms, if they exist, may be left alone or set to 0.

# %%
def weights_init_normal(m):
    """
    Applies initial weights to certain layers in a model .
    The weights are taken from a normal distribution 
    with mean = 0, std dev = 0.02.
    :param m: A module or layer in a network    
    """
    # classname will be something like:
    # `Conv`, `BatchNorm2d`, `Linear`, etc.
    classname = m.__class__.__name__

    if classname.find('Conv') != -1:
        m.weight.data.normal_(0, 0.02)
        
    if classname.find('Linear') != -1 :
        m.weight.data.normal_(0, 0.02)
        m.bias.data.fill_(0)

# %% [markdown]
# ## Build complete network
#
# Define your models' hyperparameters and instantiate the discriminator and generator from the classes defined above. Make sure you've passed in the correct input arguments.

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
def build_network(d_conv_dim, g_conv_dim, z_size):
    # define discriminator and generator
    D = Discriminator(d_conv_dim)
    G = Generator(z_size=z_size, conv_dim=g_conv_dim)

    # initialize model weights
    D.apply(weights_init_normal)
    G.apply(weights_init_normal)

    print(D)
    print()
    print(G)
    
    return D, G

# %% [markdown]
# #### Exercise: Define model hyperparameters

# %%
# Define model hyperparams
d_conv_dim = 32
g_conv_dim = 32
z_size = 100

"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
D, G = build_network(d_conv_dim, g_conv_dim, z_size)
# Out:
# Discriminator(
#   (conv1): Sequential(
#     (0): Conv2d(3, 32, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1), bias=False)
#   )
#   (conv2): Sequential(
#     (0): Conv2d(32, 64, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1), bias=False)
#     (1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   )
#   (conv3): Sequential(
#     (0): Conv2d(64, 128, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1), bias=False)
#     (1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   )
#   (conv4): Sequential(
#     (0): Conv2d(128, 256, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1), bias=False)
#     (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   )
#   (fc): Linear(in_features=1024, out_features=1, bias=True)
# )
#
# Generator(
#   (fc): Linear(in_features=100, out_features=1024, bias=True)
#   (deconv1): Sequential(
#     (0): ConvTranspose2d(256, 128, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1), bias=False)
#     (1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   )
#   (deconv2): Sequential(
#     (0): ConvTranspose2d(128, 64, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1), bias=False)
#     (1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   )
#   (deconv3): Sequential(
#     (0): ConvTranspose2d(64, 32, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1), bias=False)
#     (1): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   )
#   (deconv4): Sequential(
#     (0): ConvTranspose2d(32, 3, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1), bias=False)
#   )
# )

# %% [markdown]
# ### Training on GPU
#
# Check if you can train on GPU. Here, we'll set this as a boolean variable `train_on_gpu`. Later, you'll be responsible for making sure that
# >* Models,
# * Model inputs, and
# * Loss function arguments
#
# Are moved to GPU, where appropriate.

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
import torch

# Check for a GPU
train_on_gpu = torch.cuda.is_available()
if not train_on_gpu:
    print('No GPU found. Please use a GPU to train your neural network.')
else:
    print('Training on GPU!')
# Out:
# Training on GPU!

# %% [markdown]
# ---
# ## Discriminator and Generator Losses
#
# Now we need to calculate the losses for both types of adversarial networks.
#
# ### Discriminator Losses
#
# > * For the discriminator, the total loss is the sum of the losses for real and fake images, `d_loss = d_real_loss + d_fake_loss`.
# * Remember that we want the discriminator to output 1 for real images and 0 for fake images, so we need to set up the losses to reflect that.
#
#
# ### Generator Loss
#
# The generator loss will look similar only with flipped labels. The generator's goal is to get the discriminator to *think* its generated images are *real*.
#
# #### Exercise: Complete real and fake loss functions
#
# **You may choose to use either cross entropy or a least squares error loss to complete the following `real_loss` and `fake_loss` functions.**

# %%
def real_loss(D_out):
    '''Calculates how close discriminator outputs are to being real.
       param, D_out: discriminator logits
       return: real loss'''
    
    batch_size = D_out.size(0)
    labels = torch.ones(batch_size)
    
    if train_on_gpu:
        labels = labels.cuda()
    
    criterion = nn.BCEWithLogitsLoss()
    loss = criterion(D_out.squeeze(), labels)

    return loss

def fake_loss(D_out):
    '''Calculates how close discriminator outputs are to being fake.
       param, D_out: discriminator logits
       return: fake loss'''
    
    batch_size = D_out.size(0)
    labels = torch.zeros(batch_size)
    
    if train_on_gpu:
        labels = labels.cuda()
        
    criterion = nn.BCEWithLogitsLoss()
    loss = criterion(D_out.squeeze(), labels)

    return loss

# %% [markdown]
# ## Optimizers
#
# #### Exercise: Define optimizers for your Discriminator (D) and Generator (G)
#
# Define optimizers for your models with appropriate hyperparameters.

# %%
import torch.optim as optim

# Create optimizers for the discriminator D and generator G
d_optimizer = optim.Adam(D.parameters(), 0.0002, [0.5, 0.999])
g_optimizer = optim.Adam(G.parameters(), 0.0002, [0.5, 0.999])

# %% [markdown]
# ---
# ## Training
#
# Training will involve alternating between training the discriminator and the generator. You'll use your functions `real_loss` and `fake_loss` to help you calculate the discriminator losses.
#
# * You should train the discriminator by alternating on real and fake images
# * Then the generator, which tries to trick the discriminator and should have an opposing loss function
#
#
# #### Saving Samples
#
# You've been given some code to print out some loss statistics and save some generated "fake" samples.

# %% [markdown]
# #### Exercise: Complete the training function
#
# Keep in mind that, if you've moved your models to GPU, you'll also have to move any model inputs to GPU.

# %%
def train(D, G, n_epochs, print_every=50):
    '''Trains adversarial networks for some number of epochs
       param, D: the discriminator network
       param, G: the generator network
       param, n_epochs: number of epochs to train for
       param, print_every: when to print and record the models' losses
       return: D and G losses'''
    
    # move models to GPU
    if train_on_gpu:
        D.cuda()
        G.cuda()

    # keep track of loss and generated, "fake" samples
    samples = []
    losses = []

    # Get some fixed data for sampling. These are images that are held
    # constant throughout training, and allow us to inspect the model's performance
    sample_size=16
    fixed_z = np.random.uniform(-1, 1, size=(sample_size, z_size))
    fixed_z = torch.from_numpy(fixed_z).float()
    # move z to GPU if available
    if train_on_gpu:
        fixed_z = fixed_z.cuda()

    # epoch training loop
    for epoch in range(n_epochs):

        # batch training loop
        for batch_i, (real_images, _) in enumerate(celeba_train_loader):

            batch_size = real_images.size(0)
            real_images = scale(real_images)

            # ===============================================
            #         YOUR CODE HERE: TRAIN THE NETWORKS
            # ===============================================
            
            if train_on_gpu:
                real_images = real_images.cuda()
                
            # 1. Train the discriminator on real and fake images
            
            d_optimizer.zero_grad()
            
            # discriminator losses on real images
            d_real = D(real_images)
            d_real_loss = real_loss(d_real)
            
            # generate fake images
            z = np.random.uniform(-1, 1, size=(batch_size, z_size))
            z = torch.from_numpy(z).float()
            
            if train_on_gpu:
                z = z.cuda()
                
            fake_images = G(z)
            
            # discriminator losses on fake images
            d_fake = D(fake_images)
            d_fake_loss = fake_loss(d_fake)
            
            # sum losses          
            d_loss = d_real_loss + d_fake_loss
            
            # perform backpropagation             
            d_loss.backward()       
            d_optimizer.step()

            
            # 2. Train the generator with an adversarial loss
            
            g_optimizer.zero_grad()
            
            # generate fake images
            z = np.random.uniform(-1, 1, size=(batch_size, z_size))
            z = torch.from_numpy(z).float()
            
            if train_on_gpu:
                z = z.cuda()
                
            fake_images = G(z)
            
            # discriminator losses with flipped labels
            d_fake = D(fake_images)
            g_loss = real_loss(d_fake)
            
            # perform backpropagation         
            g_loss.backward()
            g_optimizer.step()

            
            # ===============================================
            #              END OF YOUR CODE
            # ===============================================

            # Print some loss stats
            if batch_i % print_every == 0:
                # append discriminator loss and generator loss
                losses.append((d_loss.item(), g_loss.item()))
                # print discriminator and generator loss
                print('Epoch [{:5d}/{:5d}] | d_loss: {:6.4f} | g_loss: {:6.4f}'.format(
                        epoch+1, n_epochs, d_loss.item(), g_loss.item()))


        ## AFTER EACH EPOCH##    
        # this code assumes your generator is named G, feel free to change the name
        # generate and save sample, fake images
        G.eval() # for generating samples
        samples_z = G(fixed_z)
        samples.append(samples_z)
        G.train() # back to training mode

    # Save training generator samples
    with open('train_samples.pkl', 'wb') as f:
        pkl.dump(samples, f)
    
    # finally return losses
    return losses

# %% [markdown]
# Set your number of training epochs and train your GAN!

# %%
# set number of epochs 
n_epochs = 100


"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
# call training function
losses = train(D, G, n_epochs=n_epochs)
# Out:
# Epoch [    1/  100] | d_loss: 0.7744 | g_loss: 2.8304
# Epoch [    1/  100] | d_loss: 0.6696 | g_loss: 1.9348
# Epoch [    1/  100] | d_loss: 0.8927 | g_loss: 1.2752
# Epoch [    1/  100] | d_loss: 0.6054 | g_loss: 1.4944
# Epoch [    2/  100] | d_loss: 0.4733 | g_loss: 2.5579
# Epoch [    2/  100] | d_loss: 1.3021 | g_loss: 4.6169
# Epoch [    2/  100] | d_loss: 0.5359 | g_loss: 1.9841
# Epoch [    2/  100] | d_loss: 0.7327 | g_loss: 3.4067
# Epoch [    3/  100] | d_loss: 0.3969 | g_loss: 2.6006
# Epoch [    3/  100] | d_loss: 0.7706 | g_loss: 1.5567
# Epoch [    3/  100] | d_loss: 0.7196 | g_loss: 1.4911
# Epoch [    3/  100] | d_loss: 0.7725 | g_loss: 3.3963
# Epoch [    4/  100] | d_loss: 0.8330 | g_loss: 2.3631
# Epoch [    4/  100] | d_loss: 0.7964 | g_loss: 1.2179
# Epoch [    4/  100] | d_loss: 0.7346 | g_loss: 2.5637
# Epoch [    4/  100] | d_loss: 0.6724 | g_loss: 2.1785
# Epoch [    5/  100] | d_loss: 0.6124 | g_loss: 2.0080
# Epoch [    5/  100] | d_loss: 0.4657 | g_loss: 2.2367
# Epoch [    5/  100] | d_loss: 0.5759 | g_loss: 2.8807
# Epoch [    5/  100] | d_loss: 0.6565 | g_loss: 1.9734
# Epoch [    6/  100] | d_loss: 0.7180 | g_loss: 2.7402
# Epoch [    6/  100] | d_loss: 0.7339 | g_loss: 2.8784
# Epoch [    6/  100] | d_loss: 1.0799 | g_loss: 3.0223
# Epoch [    6/  100] | d_loss: 0.9406 | g_loss: 2.9334
# Epoch [    7/  100] | d_loss: 0.6322 | g_loss: 2.4775
# Epoch [    7/  100] | d_loss: 0.5670 | g_loss: 1.3269
# Epoch [    7/  100] | d_loss: 0.5961 | g_loss: 1.7340
# Epoch [    7/  100] | d_loss: 0.4680 | g_loss: 2.0489
# Epoch [    8/  100] | d_loss: 0.7697 | g_loss: 0.9864
# Epoch [    8/  100] | d_loss: 0.6156 | g_loss: 2.0274
# Epoch [    8/  100] | d_loss: 0.6964 | g_loss: 1.8624
# Epoch [    8/  100] | d_loss: 0.7014 | g_loss: 1.1229
# Epoch [    9/  100] | d_loss: 0.5836 | g_loss: 2.9119
# Epoch [    9/  100] | d_loss: 0.5270 | g_loss: 1.7576
# Epoch [    9/  100] | d_loss: 0.6137 | g_loss: 2.4467
# Epoch [    9/  100] | d_loss: 0.8199 | g_loss: 3.0057
# Epoch [   10/  100] | d_loss: 0.5428 | g_loss: 2.4458
# Epoch [   10/  100] | d_loss: 0.5130 | g_loss: 2.0490
# Epoch [   10/  100] | d_loss: 0.6559 | g_loss: 2.1673
# Epoch [   10/  100] | d_loss: 0.6256 | g_loss: 1.3972
# Epoch [   11/  100] | d_loss: 0.9146 | g_loss: 1.4226
# Epoch [   11/  100] | d_loss: 0.7643 | g_loss: 0.4776
# Epoch [   11/  100] | d_loss: 1.3178 | g_loss: 1.5236
# Epoch [   11/  100] | d_loss: 0.5329 | g_loss: 2.2121
# Epoch [   12/  100] | d_loss: 0.5743 | g_loss: 2.5167
# Epoch [   12/  100] | d_loss: 0.9277 | g_loss: 0.8656
# Epoch [   12/  100] | d_loss: 0.5488 | g_loss: 1.6433
# Epoch [   12/  100] | d_loss: 0.5406 | g_loss: 1.8274
# Epoch [   13/  100] | d_loss: 0.6839 | g_loss: 1.2199
# Epoch [   13/  100] | d_loss: 0.5627 | g_loss: 1.8531
# Epoch [   13/  100] | d_loss: 0.7217 | g_loss: 2.6585
# Epoch [   13/  100] | d_loss: 1.1084 | g_loss: 4.7080
# Epoch [   14/  100] | d_loss: 0.4668 | g_loss: 2.4901
# Epoch [   14/  100] | d_loss: 0.5260 | g_loss: 1.8596
# Epoch [   14/  100] | d_loss: 1.0588 | g_loss: 0.6825
# Epoch [   14/  100] | d_loss: 0.6231 | g_loss: 1.3683
# Epoch [   15/  100] | d_loss: 0.4712 | g_loss: 2.7006
# Epoch [   15/  100] | d_loss: 0.6215 | g_loss: 3.8200
# Epoch [   15/  100] | d_loss: 0.7267 | g_loss: 1.7818
# Epoch [   15/  100] | d_loss: 0.5929 | g_loss: 2.0417
# Epoch [   16/  100] | d_loss: 0.4751 | g_loss: 2.0684
# Epoch [   16/  100] | d_loss: 0.5408 | g_loss: 1.9875
# Epoch [   16/  100] | d_loss: 0.7986 | g_loss: 1.1802
# Epoch [   16/  100] | d_loss: 0.7311 | g_loss: 2.9185
# Epoch [   17/  100] | d_loss: 0.8925 | g_loss: 1.3850
# Epoch [   17/  100] | d_loss: 0.6464 | g_loss: 2.8320
# Epoch [   17/  100] | d_loss: 0.3581 | g_loss: 2.2073
# Epoch [   17/  100] | d_loss: 0.5301 | g_loss: 2.6242
# Epoch [   18/  100] | d_loss: 2.7106 | g_loss: 1.1876
# Epoch [   18/  100] | d_loss: 0.6059 | g_loss: 1.7491
# Epoch [   18/  100] | d_loss: 0.5052 | g_loss: 2.7228
# Epoch [   18/  100] | d_loss: 0.4333 | g_loss: 1.8746
# Epoch [   19/  100] | d_loss: 0.4481 | g_loss: 3.2973
# Epoch [   19/  100] | d_loss: 0.4684 | g_loss: 1.8876
# Epoch [   19/  100] | d_loss: 0.6919 | g_loss: 2.7152
# Epoch [   19/  100] | d_loss: 0.5215 | g_loss: 2.4030
# Epoch [   20/  100] | d_loss: 0.4676 | g_loss: 2.5176
# Epoch [   20/  100] | d_loss: 1.7459 | g_loss: 4.3478
# Epoch [   20/  100] | d_loss: 0.4567 | g_loss: 1.7575
# Epoch [   20/  100] | d_loss: 0.5541 | g_loss: 2.9525
# Epoch [   21/  100] | d_loss: 0.5723 | g_loss: 1.6748
# Epoch [   21/  100] | d_loss: 0.3495 | g_loss: 2.7446
# Epoch [   21/  100] | d_loss: 0.3044 | g_loss: 1.5155
# Epoch [   21/  100] | d_loss: 0.3898 | g_loss: 2.3035
# Epoch [   22/  100] | d_loss: 0.8646 | g_loss: 5.0192
# Epoch [   22/  100] | d_loss: 0.4547 | g_loss: 2.7840
# Epoch [   22/  100] | d_loss: 0.5465 | g_loss: 1.6191
# Epoch [   22/  100] | d_loss: 0.4557 | g_loss: 2.9280
# Epoch [   23/  100] | d_loss: 0.8799 | g_loss: 3.7787
# Epoch [   23/  100] | d_loss: 0.3418 | g_loss: 2.9496
# Epoch [   23/  100] | d_loss: 0.3036 | g_loss: 3.9359
# Epoch [   23/  100] | d_loss: 0.3467 | g_loss: 2.4057
# Epoch [   24/  100] | d_loss: 0.4866 | g_loss: 2.6368
# Epoch [   24/  100] | d_loss: 0.5386 | g_loss: 3.5200
# Epoch [   24/  100] | d_loss: 0.4075 | g_loss: 2.8225
# Epoch [   24/  100] | d_loss: 0.5532 | g_loss: 1.5956
# Epoch [   25/  100] | d_loss: 0.4693 | g_loss: 3.3713
# Epoch [   25/  100] | d_loss: 0.7504 | g_loss: 3.6403
# Epoch [   25/  100] | d_loss: 0.3568 | g_loss: 2.6741
# Epoch [   25/  100] | d_loss: 0.4264 | g_loss: 2.9325
# Epoch [   26/  100] | d_loss: 0.7614 | g_loss: 4.6806
# Epoch [   26/  100] | d_loss: 0.5269 | g_loss: 4.0211
# Epoch [   26/  100] | d_loss: 0.2521 | g_loss: 3.6702
# Epoch [   26/  100] | d_loss: 0.7222 | g_loss: 4.2267
# Epoch [   27/  100] | d_loss: 0.4675 | g_loss: 1.8812
# Epoch [   27/  100] | d_loss: 0.6079 | g_loss: 3.7000
# Epoch [   27/  100] | d_loss: 0.2754 | g_loss: 2.7278
# Epoch [   27/  100] | d_loss: 0.3625 | g_loss: 2.3488
# Epoch [   28/  100] | d_loss: 0.4842 | g_loss: 2.5976
# Epoch [   28/  100] | d_loss: 0.3244 | g_loss: 2.5886
# Epoch [   28/  100] | d_loss: 0.8587 | g_loss: 4.7169
# Epoch [   28/  100] | d_loss: 0.3407 | g_loss: 2.5753
# Epoch [   29/  100] | d_loss: 0.7078 | g_loss: 2.1781
# Epoch [   29/  100] | d_loss: 0.4645 | g_loss: 1.6564
# Epoch [   29/  100] | d_loss: 0.3094 | g_loss: 2.7232
# Epoch [   29/  100] | d_loss: 0.6829 | g_loss: 1.3954
# Epoch [   30/  100] | d_loss: 0.2601 | g_loss: 2.8163
# Epoch [   30/  100] | d_loss: 0.3973 | g_loss: 1.8398
# Epoch [   30/  100] | d_loss: 0.3263 | g_loss: 1.8241
# Epoch [   30/  100] | d_loss: 0.5020 | g_loss: 2.4488
# Epoch [   31/  100] | d_loss: 0.6600 | g_loss: 5.3896
# Epoch [   31/  100] | d_loss: 0.3202 | g_loss: 3.1830
# Epoch [   31/  100] | d_loss: 0.4655 | g_loss: 3.9165
# Epoch [   31/  100] | d_loss: 0.7209 | g_loss: 4.9100
# Epoch [   32/  100] | d_loss: 0.3824 | g_loss: 1.6664
# Epoch [   32/  100] | d_loss: 0.2345 | g_loss: 3.0727
# Epoch [   32/  100] | d_loss: 0.3044 | g_loss: 3.1464
# Epoch [   32/  100] | d_loss: 0.2674 | g_loss: 2.3150
# Epoch [   33/  100] | d_loss: 0.4704 | g_loss: 3.5415
# Epoch [   33/  100] | d_loss: 0.3456 | g_loss: 2.3359
# Epoch [   33/  100] | d_loss: 0.2749 | g_loss: 3.5920
# Epoch [   33/  100] | d_loss: 0.7767 | g_loss: 3.0781
# Epoch [   34/  100] | d_loss: 0.3399 | g_loss: 2.4824
# Epoch [   34/  100] | d_loss: 0.3468 | g_loss: 2.7465
# Epoch [   34/  100] | d_loss: 0.3972 | g_loss: 2.5121
# Epoch [   34/  100] | d_loss: 0.5737 | g_loss: 1.7851
# Epoch [   35/  100] | d_loss: 0.2894 | g_loss: 3.5224
# Epoch [   35/  100] | d_loss: 0.2988 | g_loss: 2.4418
# Epoch [   35/  100] | d_loss: 0.4493 | g_loss: 1.3507
# Epoch [   35/  100] | d_loss: 0.3910 | g_loss: 2.7997
# Epoch [   36/  100] | d_loss: 0.1880 | g_loss: 3.3883
# Epoch [   36/  100] | d_loss: 0.2914 | g_loss: 2.3524
# Epoch [   36/  100] | d_loss: 0.3060 | g_loss: 3.5012
# Epoch [   36/  100] | d_loss: 0.4184 | g_loss: 3.5464
# Epoch [   37/  100] | d_loss: 0.2693 | g_loss: 2.5383
# Epoch [   37/  100] | d_loss: 0.1622 | g_loss: 3.1023
# Epoch [   37/  100] | d_loss: 0.4307 | g_loss: 2.1843
# Epoch [   37/  100] | d_loss: 0.3316 | g_loss: 2.9111
# Epoch [   38/  100] | d_loss: 0.2626 | g_loss: 3.0741
# Epoch [   38/  100] | d_loss: 0.5257 | g_loss: 2.3771
# Epoch [   38/  100] | d_loss: 0.2299 | g_loss: 2.3315
# Epoch [   38/  100] | d_loss: 0.5104 | g_loss: 4.8520
# Epoch [   39/  100] | d_loss: 0.2951 | g_loss: 3.2434
# Epoch [   39/  100] | d_loss: 3.7672 | g_loss: 1.8039
# Epoch [   39/  100] | d_loss: 0.2488 | g_loss: 3.0464
# Epoch [   39/  100] | d_loss: 0.3627 | g_loss: 2.3781
# Epoch [   40/  100] | d_loss: 0.2079 | g_loss: 3.8428
# Epoch [   40/  100] | d_loss: 0.2463 | g_loss: 2.9127
# Epoch [   40/  100] | d_loss: 0.2683 | g_loss: 3.6196
# Epoch [   40/  100] | d_loss: 0.2341 | g_loss: 2.8382
# Epoch [   41/  100] | d_loss: 0.2641 | g_loss: 4.8243
# Epoch [   41/  100] | d_loss: 0.1473 | g_loss: 3.0761
# Epoch [   41/  100] | d_loss: 0.2837 | g_loss: 4.0245
# Epoch [   41/  100] | d_loss: 0.2492 | g_loss: 3.5917
# Epoch [   42/  100] | d_loss: 0.3445 | g_loss: 2.6726
# Epoch [   42/  100] | d_loss: 0.3230 | g_loss: 2.1103
# Epoch [   42/  100] | d_loss: 0.2137 | g_loss: 3.2164
# Epoch [   42/  100] | d_loss: 0.2471 | g_loss: 3.5037
# Epoch [   43/  100] | d_loss: 0.4010 | g_loss: 4.0549
# Epoch [   43/  100] | d_loss: 0.1748 | g_loss: 2.3782
# Epoch [   43/  100] | d_loss: 0.3700 | g_loss: 2.0781
# Epoch [   43/  100] | d_loss: 0.4592 | g_loss: 4.0943
# Epoch [   44/  100] | d_loss: 0.4401 | g_loss: 2.6110
# Epoch [   44/  100] | d_loss: 0.5266 | g_loss: 4.0877
# Epoch [   44/  100] | d_loss: 0.7059 | g_loss: 5.5118
# Epoch [   44/  100] | d_loss: 0.3870 | g_loss: 2.3493
# Epoch [   45/  100] | d_loss: 0.2850 | g_loss: 3.6822
# Epoch [   45/  100] | d_loss: 0.3839 | g_loss: 4.2082
# Epoch [   45/  100] | d_loss: 0.6433 | g_loss: 4.3518
# Epoch [   45/  100] | d_loss: 0.2903 | g_loss: 2.6173
# Epoch [   46/  100] | d_loss: 0.2770 | g_loss: 1.8672
# Epoch [   46/  100] | d_loss: 0.2037 | g_loss: 2.6118
# Epoch [   46/  100] | d_loss: 0.3725 | g_loss: 3.9801
# Epoch [   46/  100] | d_loss: 0.4017 | g_loss: 1.8423
# Epoch [   47/  100] | d_loss: 1.3281 | g_loss: 3.9707
# Epoch [   47/  100] | d_loss: 0.2620 | g_loss: 3.5096
# Epoch [   47/  100] | d_loss: 0.4826 | g_loss: 4.9259
# Epoch [   47/  100] | d_loss: 0.3175 | g_loss: 3.1099
# Epoch [   48/  100] | d_loss: 1.4079 | g_loss: 6.7301
# Epoch [   48/  100] | d_loss: 0.4136 | g_loss: 4.0174
# Epoch [   48/  100] | d_loss: 0.3388 | g_loss: 3.9782
# Epoch [   48/  100] | d_loss: 0.2712 | g_loss: 3.7747
# Epoch [   49/  100] | d_loss: 0.2028 | g_loss: 3.6663
# Epoch [   49/  100] | d_loss: 0.3532 | g_loss: 2.7205
# Epoch [   49/  100] | d_loss: 0.1854 | g_loss: 4.0443
# Epoch [   49/  100] | d_loss: 0.3150 | g_loss: 2.3013
# Epoch [   50/  100] | d_loss: 0.5973 | g_loss: 4.3600
# Epoch [   50/  100] | d_loss: 0.3201 | g_loss: 4.2603
# Epoch [   50/  100] | d_loss: 0.3467 | g_loss: 3.1584
# Epoch [   50/  100] | d_loss: 0.8655 | g_loss: 5.0902
# Epoch [   51/  100] | d_loss: 0.1386 | g_loss: 4.6098
# Epoch [   51/  100] | d_loss: 0.2069 | g_loss: 3.7264
# Epoch [   51/  100] | d_loss: 0.2993 | g_loss: 3.0613
# Epoch [   51/  100] | d_loss: 0.2995 | g_loss: 3.1908
# Epoch [   52/  100] | d_loss: 0.3294 | g_loss: 3.4454
# Epoch [   52/  100] | d_loss: 0.2112 | g_loss: 3.4092
# Epoch [   52/  100] | d_loss: 0.2290 | g_loss: 3.8356
# Epoch [   52/  100] | d_loss: 0.1395 | g_loss: 3.9802
# Epoch [   53/  100] | d_loss: 0.2513 | g_loss: 2.7072
# Epoch [   53/  100] | d_loss: 0.2871 | g_loss: 2.1368
# Epoch [   53/  100] | d_loss: 0.1760 | g_loss: 5.5981
# Epoch [   53/  100] | d_loss: 0.1446 | g_loss: 4.3100
# Epoch [   54/  100] | d_loss: 0.2534 | g_loss: 2.6851
# Epoch [   54/  100] | d_loss: 0.2980 | g_loss: 2.7296
# Epoch [   54/  100] | d_loss: 0.2461 | g_loss: 3.0298
# Epoch [   54/  100] | d_loss: 0.4684 | g_loss: 5.2573
# Epoch [   55/  100] | d_loss: 0.1713 | g_loss: 4.1163
# Epoch [   55/  100] | d_loss: 0.2845 | g_loss: 3.3722
# Epoch [   55/  100] | d_loss: 0.4050 | g_loss: 5.3993
# Epoch [   55/  100] | d_loss: 0.1242 | g_loss: 3.1868
# Epoch [   56/  100] | d_loss: 0.1489 | g_loss: 3.3079
# Epoch [   56/  100] | d_loss: 0.2837 | g_loss: 4.2005
# Epoch [   56/  100] | d_loss: 0.2454 | g_loss: 3.2734
# Epoch [   56/  100] | d_loss: 0.7464 | g_loss: 5.2448
# Epoch [   57/  100] | d_loss: 0.4922 | g_loss: 3.1655
# Epoch [   57/  100] | d_loss: 0.1744 | g_loss: 3.6942
# Epoch [   57/  100] | d_loss: 0.2834 | g_loss: 1.7388
# Epoch [   57/  100] | d_loss: 0.2246 | g_loss: 3.1065
# Epoch [   58/  100] | d_loss: 0.2046 | g_loss: 4.3971
# Epoch [   58/  100] | d_loss: 0.1760 | g_loss: 5.3605
# Epoch [   58/  100] | d_loss: 0.1484 | g_loss: 4.0380
# Epoch [   58/  100] | d_loss: 0.1486 | g_loss: 2.3316
# Epoch [   59/  100] | d_loss: 0.2346 | g_loss: 3.1928
# Epoch [   59/  100] | d_loss: 0.2055 | g_loss: 3.5303
# Epoch [   59/  100] | d_loss: 0.1541 | g_loss: 3.3316
# Epoch [   59/  100] | d_loss: 0.3185 | g_loss: 2.3995
# Epoch [   60/  100] | d_loss: 0.2445 | g_loss: 4.1141
# Epoch [   60/  100] | d_loss: 0.3668 | g_loss: 5.6934
# Epoch [   60/  100] | d_loss: 0.1202 | g_loss: 3.5539
# Epoch [   60/  100] | d_loss: 0.1159 | g_loss: 4.9676
# Epoch [   61/  100] | d_loss: 1.5610 | g_loss: 1.1678
# Epoch [   61/  100] | d_loss: 0.2704 | g_loss: 3.2783
# Epoch [   61/  100] | d_loss: 0.2635 | g_loss: 3.5947
# Epoch [   61/  100] | d_loss: 0.1317 | g_loss: 3.3734
# Epoch [   62/  100] | d_loss: 0.2348 | g_loss: 3.7137
# Epoch [   62/  100] | d_loss: 0.4824 | g_loss: 1.0434
# Epoch [   62/  100] | d_loss: 0.1135 | g_loss: 3.9845
# Epoch [   62/  100] | d_loss: 0.5937 | g_loss: 2.1704
# Epoch [   63/  100] | d_loss: 0.2227 | g_loss: 4.5942
# Epoch [   63/  100] | d_loss: 0.6829 | g_loss: 5.2438
# Epoch [   63/  100] | d_loss: 0.0860 | g_loss: 4.2811
# Epoch [   63/  100] | d_loss: 0.3143 | g_loss: 2.4985
# Epoch [   64/  100] | d_loss: 1.4572 | g_loss: 1.2323
# Epoch [   64/  100] | d_loss: 0.1039 | g_loss: 5.0828
# Epoch [   64/  100] | d_loss: 0.1493 | g_loss: 2.3512
# Epoch [   64/  100] | d_loss: 0.2783 | g_loss: 3.9777
# Epoch [   65/  100] | d_loss: 0.4155 | g_loss: 3.1715
# Epoch [   65/  100] | d_loss: 0.2529 | g_loss: 5.0502
# Epoch [   65/  100] | d_loss: 0.1160 | g_loss: 3.8490
# Epoch [   65/  100] | d_loss: 0.1660 | g_loss: 4.2839
# Epoch [   66/  100] | d_loss: 0.2400 | g_loss: 4.3331
# Epoch [   66/  100] | d_loss: 0.1393 | g_loss: 4.4034
# Epoch [   66/  100] | d_loss: 0.6987 | g_loss: 2.9326
# Epoch [   66/  100] | d_loss: 0.7617 | g_loss: 5.2183
# Epoch [   67/  100] | d_loss: 0.3659 | g_loss: 6.3193
# Epoch [   67/  100] | d_loss: 0.4512 | g_loss: 4.4273
# Epoch [   67/  100] | d_loss: 0.1428 | g_loss: 3.6880
# Epoch [   67/  100] | d_loss: 0.1855 | g_loss: 4.8805
# Epoch [   68/  100] | d_loss: 0.3639 | g_loss: 5.7799
# Epoch [   68/  100] | d_loss: 0.2234 | g_loss: 3.0371
# Epoch [   68/  100] | d_loss: 0.1516 | g_loss: 4.3020
# Epoch [   68/  100] | d_loss: 0.1852 | g_loss: 3.8870
# Epoch [   69/  100] | d_loss: 0.1572 | g_loss: 4.4913
# Epoch [   69/  100] | d_loss: 0.1187 | g_loss: 3.8857
# Epoch [   69/  100] | d_loss: 0.2073 | g_loss: 3.6798
# Epoch [   69/  100] | d_loss: 0.2547 | g_loss: 1.8532
# Epoch [   70/  100] | d_loss: 0.2797 | g_loss: 5.1851
# Epoch [   70/  100] | d_loss: 0.0631 | g_loss: 4.4496
# Epoch [   70/  100] | d_loss: 0.1199 | g_loss: 5.0431
# Epoch [   70/  100] | d_loss: 0.1458 | g_loss: 3.6822
# Epoch [   71/  100] | d_loss: 0.1316 | g_loss: 3.5468
# Epoch [   71/  100] | d_loss: 0.3824 | g_loss: 1.7106
# Epoch [   71/  100] | d_loss: 0.1133 | g_loss: 3.3455
# Epoch [   71/  100] | d_loss: 0.8558 | g_loss: 3.4163
# Epoch [   72/  100] | d_loss: 0.1417 | g_loss: 4.7812
# Epoch [   72/  100] | d_loss: 0.2585 | g_loss: 4.9824
# Epoch [   72/  100] | d_loss: 0.0850 | g_loss: 4.7781
# Epoch [   72/  100] | d_loss: 0.2712 | g_loss: 2.4228
# Epoch [   73/  100] | d_loss: 0.1674 | g_loss: 4.6851
# Epoch [   73/  100] | d_loss: 0.2535 | g_loss: 2.5959
# Epoch [   73/  100] | d_loss: 0.1351 | g_loss: 4.0535
# Epoch [   73/  100] | d_loss: 0.2069 | g_loss: 2.3604
# Epoch [   74/  100] | d_loss: 0.4886 | g_loss: 1.0256
# Epoch [   74/  100] | d_loss: 0.3324 | g_loss: 2.9411
# Epoch [   74/  100] | d_loss: 0.1208 | g_loss: 3.3745
# Epoch [   74/  100] | d_loss: 0.1373 | g_loss: 5.6683
# Epoch [   75/  100] | d_loss: 0.1267 | g_loss: 4.3338
# Epoch [   75/  100] | d_loss: 0.1699 | g_loss: 1.8936
# Epoch [   75/  100] | d_loss: 0.1647 | g_loss: 3.5867
# Epoch [   75/  100] | d_loss: 0.1501 | g_loss: 4.3896
# Epoch [   76/  100] | d_loss: 0.1796 | g_loss: 3.0400
# Epoch [   76/  100] | d_loss: 0.2183 | g_loss: 3.2628
# Epoch [   76/  100] | d_loss: 0.1529 | g_loss: 4.6751
# Epoch [   76/  100] | d_loss: 0.7387 | g_loss: 0.7168
# Epoch [   77/  100] | d_loss: 0.2650 | g_loss: 2.8049
# Epoch [   77/  100] | d_loss: 0.1762 | g_loss: 4.5197
# Epoch [   77/  100] | d_loss: 0.1884 | g_loss: 4.1015
# Epoch [   77/  100] | d_loss: 0.1513 | g_loss: 4.0592
# Epoch [   78/  100] | d_loss: 0.1124 | g_loss: 4.8311
# Epoch [   78/  100] | d_loss: 0.2413 | g_loss: 3.8420
# Epoch [   78/  100] | d_loss: 0.1716 | g_loss: 5.4671
# Epoch [   78/  100] | d_loss: 0.2576 | g_loss: 3.5102
# Epoch [   79/  100] | d_loss: 0.1909 | g_loss: 4.1399
# Epoch [   79/  100] | d_loss: 0.0937 | g_loss: 3.6727
# Epoch [   79/  100] | d_loss: 0.1474 | g_loss: 3.3731
# Epoch [   79/  100] | d_loss: 0.6836 | g_loss: 1.7674
# Epoch [   80/  100] | d_loss: 0.2471 | g_loss: 5.8322
# Epoch [   80/  100] | d_loss: 0.5383 | g_loss: 4.7539
# Epoch [   80/  100] | d_loss: 2.8725 | g_loss: 4.2993
# Epoch [   80/  100] | d_loss: 0.2516 | g_loss: 5.1956
# Epoch [   81/  100] | d_loss: 0.0636 | g_loss: 5.4961
# Epoch [   81/  100] | d_loss: 0.0663 | g_loss: 6.7193
# Epoch [   81/  100] | d_loss: 0.0629 | g_loss: 3.7038
# Epoch [   81/  100] | d_loss: 0.0614 | g_loss: 4.9015
# Epoch [   82/  100] | d_loss: 0.2224 | g_loss: 4.6222
# Epoch [   82/  100] | d_loss: 0.1344 | g_loss: 3.7059
# Epoch [   82/  100] | d_loss: 0.0680 | g_loss: 3.8699
# Epoch [   82/  100] | d_loss: 0.2560 | g_loss: 4.5927
# Epoch [   83/  100] | d_loss: 0.3613 | g_loss: 6.1839
# Epoch [   83/  100] | d_loss: 0.1101 | g_loss: 4.3221
# Epoch [   83/  100] | d_loss: 0.1632 | g_loss: 3.1947
# Epoch [   83/  100] | d_loss: 0.0843 | g_loss: 4.5484
# Epoch [   84/  100] | d_loss: 0.7705 | g_loss: 6.7934
# Epoch [   84/  100] | d_loss: 0.2642 | g_loss: 2.8927
# Epoch [   84/  100] | d_loss: 0.1530 | g_loss: 5.5884
# Epoch [   84/  100] | d_loss: 0.1240 | g_loss: 3.2431
# Epoch [   85/  100] | d_loss: 0.0711 | g_loss: 4.6306
# Epoch [   85/  100] | d_loss: 0.2096 | g_loss: 3.2649
# Epoch [   85/  100] | d_loss: 0.1243 | g_loss: 3.8722
# Epoch [   85/  100] | d_loss: 0.1489 | g_loss: 2.8171
# Epoch [   86/  100] | d_loss: 0.0731 | g_loss: 4.0711
# Epoch [   86/  100] | d_loss: 0.2373 | g_loss: 3.7300
# Epoch [   86/  100] | d_loss: 0.1357 | g_loss: 3.2595
# Epoch [   86/  100] | d_loss: 0.0759 | g_loss: 4.4848
# Epoch [   87/  100] | d_loss: 0.2387 | g_loss: 4.0890
# Epoch [   87/  100] | d_loss: 0.1144 | g_loss: 5.7561
# Epoch [   87/  100] | d_loss: 0.0804 | g_loss: 5.5921
# Epoch [   87/  100] | d_loss: 0.2239 | g_loss: 2.3753
# Epoch [   88/  100] | d_loss: 0.5755 | g_loss: 6.4862
# Epoch [   88/  100] | d_loss: 0.0687 | g_loss: 4.7798
# Epoch [   88/  100] | d_loss: 0.1982 | g_loss: 2.5451
# Epoch [   88/  100] | d_loss: 0.1429 | g_loss: 3.5479
# Epoch [   89/  100] | d_loss: 0.2637 | g_loss: 3.9849
# Epoch [   89/  100] | d_loss: 0.2625 | g_loss: 3.4503
# Epoch [   89/  100] | d_loss: 0.1232 | g_loss: 4.7706
# Epoch [   89/  100] | d_loss: 0.2966 | g_loss: 2.7693
# Epoch [   90/  100] | d_loss: 0.1225 | g_loss: 4.2975
# Epoch [   90/  100] | d_loss: 0.1380 | g_loss: 4.3074
# Epoch [   90/  100] | d_loss: 0.1729 | g_loss: 6.1207
# Epoch [   90/  100] | d_loss: 0.0759 | g_loss: 4.7104
# Epoch [   91/  100] | d_loss: 0.2564 | g_loss: 6.8082
# Epoch [   91/  100] | d_loss: 0.2396 | g_loss: 3.1518
# Epoch [   91/  100] | d_loss: 0.0892 | g_loss: 4.6042
# Epoch [   91/  100] | d_loss: 0.0912 | g_loss: 3.6013
# Epoch [   92/  100] | d_loss: 0.1001 | g_loss: 3.2442
# Epoch [   92/  100] | d_loss: 0.2415 | g_loss: 1.4676
# Epoch [   92/  100] | d_loss: 0.1164 | g_loss: 4.1297
# Epoch [   92/  100] | d_loss: 0.5684 | g_loss: 2.9746
# Epoch [   93/  100] | d_loss: 0.2487 | g_loss: 4.6257
# Epoch [   93/  100] | d_loss: 0.1415 | g_loss: 3.7437
# Epoch [   93/  100] | d_loss: 0.4052 | g_loss: 3.9043
# Epoch [   93/  100] | d_loss: 0.1225 | g_loss: 4.5502
# Epoch [   94/  100] | d_loss: 0.1614 | g_loss: 5.0662
# Epoch [   94/  100] | d_loss: 0.1085 | g_loss: 3.7851
# Epoch [   94/  100] | d_loss: 0.1422 | g_loss: 3.3535
# Epoch [   94/  100] | d_loss: 0.2054 | g_loss: 4.1354
# Epoch [   95/  100] | d_loss: 0.2792 | g_loss: 3.1082
# Epoch [   95/  100] | d_loss: 0.1615 | g_loss: 3.1528
# Epoch [   95/  100] | d_loss: 0.0805 | g_loss: 4.3858
# Epoch [   95/  100] | d_loss: 0.0607 | g_loss: 5.4267
# Epoch [   96/  100] | d_loss: 1.5360 | g_loss: 3.6758
# Epoch [   96/  100] | d_loss: 0.2218 | g_loss: 3.7961
# Epoch [   96/  100] | d_loss: 0.1682 | g_loss: 2.4869
# Epoch [   96/  100] | d_loss: 0.1076 | g_loss: 2.7306
# Epoch [   97/  100] | d_loss: 0.1461 | g_loss: 5.5721
# Epoch [   97/  100] | d_loss: 0.0703 | g_loss: 3.9784
# Epoch [   97/  100] | d_loss: 0.5375 | g_loss: 1.3105
# Epoch [   97/  100] | d_loss: 0.1895 | g_loss: 4.9129
# Epoch [   98/  100] | d_loss: 0.1822 | g_loss: 4.5982
# Epoch [   98/  100] | d_loss: 0.1128 | g_loss: 4.8661
# Epoch [   98/  100] | d_loss: 0.1960 | g_loss: 3.3040
# Epoch [   98/  100] | d_loss: 0.0848 | g_loss: 4.2331
# Epoch [   99/  100] | d_loss: 0.0866 | g_loss: 3.2143
# Epoch [   99/  100] | d_loss: 0.0897 | g_loss: 4.5782
# Epoch [   99/  100] | d_loss: 0.0472 | g_loss: 4.2136
# Epoch [   99/  100] | d_loss: 0.3566 | g_loss: 1.6760
# Epoch [  100/  100] | d_loss: 0.0411 | g_loss: 5.6546
# Epoch [  100/  100] | d_loss: 0.1012 | g_loss: 5.0625
# Epoch [  100/  100] | d_loss: 0.4625 | g_loss: 0.9349
# Epoch [  100/  100] | d_loss: 0.1601 | g_loss: 4.2179

# %% [markdown]
# ## Training loss
#
# Plot the training losses for the generator and discriminator, recorded after each epoch.

# %%
fig, ax = plt.subplots()
losses = np.array(losses)
plt.plot(losses.T[0], label='Discriminator', alpha=0.5)
plt.plot(losses.T[1], label='Generator', alpha=0.5)
plt.title("Training Losses")
plt.legend()

# %% [markdown]
# ## Generator samples from training
#
# View samples of images from the generator, and answer a question about the strengths and weaknesses of your trained models.

# %%
# helper function for viewing a list of passed in sample images
def view_samples(epoch, samples):
    fig, axes = plt.subplots(figsize=(16,4), nrows=2, ncols=8, sharey=True, sharex=True)
    for ax, img in zip(axes.flatten(), samples[epoch]):
        img = img.detach().cpu().numpy()
        img = np.transpose(img, (1, 2, 0))
        img = ((img + 1)*255 / (2)).astype(np.uint8)
        ax.xaxis.set_visible(False)
        ax.yaxis.set_visible(False)
        im = ax.imshow(img.reshape((32,32,3)))

# %%
# Load samples from generator, taken while training
with open('train_samples.pkl', 'rb') as f:
    samples = pkl.load(f)

# %%
_ = view_samples(-1, samples)

# %% [markdown]
# ### Question: What do you notice about your generated samples and how might you improve this model?
# When you answer this question, consider the following factors:
# * The dataset is biased; it is made of "celebrity" faces that are mostly white
# * Model size; larger models have the opportunity to learn more features in a data feature space
# * Optimization strategy; optimizers and number of epochs affect your final result

# %% [markdown]
# **Answer:**
#
# - model could be improved by using more images, in a higher resolution;
# - creating deeper model could improve the quality of generated faces - create more realistic faces - currently faces are a bit blurred;
# - current dataset contains only celebrity faces, and most of tthem from white people - we could improve model by providing more images, with equal distribution of races;

# %% [markdown]
# ### Submitting This Project
# When submitting this project, make sure to run all the cells before saving the notebook. Save the notebook file as "dlnd_face_generation.ipynb" and save it as a HTML file under "File" -> "Download as". Include the "problem_unittests.py" files in your submission.
